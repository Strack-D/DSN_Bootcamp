# %%
#importation of necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#load Housing Data
raw_data = pd.read_csv('dataset/Housing_dataset_train.csv')
housingDataTest = pd.read_csv('dataset/Housing_dataset_test.csv')

# %% [markdown]
# # Basic Data Exploration

# %%
raw_data.head()
# Out:
#       ID      loc                 title  bedroom  bathroom  parking_space  \
# 0   3583  Katsina  Semi-detached duplex      2.0       2.0            1.0
# 1   2748     Ondo             Apartment      NaN       2.0            4.0
# 2   9261    Ekiti                   NaN      7.0       5.0            NaN
# 3   2224  Anambra       Detached duplex      5.0       2.0            4.0
# 4  10300     Kogi        Terrace duplex      NaN       5.0            6.0
#
#          price
# 0  1149999.565
# 1  1672416.689
# 2  3364799.814
# 3  2410306.756
# 4  2600700.898

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             14000 non-null  int64
#  1   loc            12187 non-null  object
#  2   title          12278 non-null  object
#  3   bedroom        12201 non-null  float64
#  4   bathroom       12195 non-null  float64
#  5   parking_space  12189 non-null  float64
#  6   price          14000 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 765.8+ KB

# %%
housingDataTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             6000 non-null   int64
#  1   loc            6000 non-null   object
#  2   title          6000 non-null   object
#  3   bedroom        6000 non-null   int64
#  4   bathroom       6000 non-null   int64
#  5   parking_space  6000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 281.4+ KB

# %%
raw_data.describe()
# Out:
#                  ID       bedroom      bathroom  parking_space         price
# count  14000.000000  12201.000000  12195.000000   12189.000000  1.400000e+04
# mean    4862.700357      4.308171      3.134235       3.169825  2.138082e+06
# std     3818.348214      2.441165      2.035950       1.599415  1.083057e+06
# min        0.000000      1.000000      1.000000       1.000000  4.319673e+05
# 25%     1672.750000      2.000000      1.000000       2.000000  1.393990e+06
# 50%     3527.000000      4.000000      2.000000       3.000000  1.895223e+06
# 75%     8011.250000      6.000000      5.000000       4.000000  2.586699e+06
# max    12999.000000      9.000000      7.000000       6.000000  1.656849e+07

# %% [markdown]
# # Data Cleaning

# %%
raw_data.isnull().sum()
# Out:
# ID                  0
# loc              1813
# title            1722
# bedroom          1799
# bathroom         1805
# parking_space    1811
# price               0
# dtype: int64

# %%
columns = raw_data.columns

# %%
house_types = raw_data['title'].unique()

# %%
raw_data.groupby('title')[['bedroom', 'bathroom', 'parking_space', 'price']].mean()
# Out:
#                        bedroom  bathroom  parking_space         price
# title
# Apartment             4.344219  3.109862       3.285714  1.567004e+06
# Bungalow              4.402852  3.394664       3.192619  1.733845e+06
# Cottage               2.905512  1.510363       2.542714  1.307817e+06
# Detached duplex       4.327840  3.232270       3.230906  2.205883e+06
# Flat                  4.378877  3.188295       3.146486  1.721875e+06
# Mansion               4.333929  3.197880       3.115114  3.725768e+06
# Penthouse             4.342982  2.986667       3.225177  2.628945e+06
# Semi-detached duplex  4.414903  3.194770       3.202912  1.918468e+06
# Terrace duplex        4.340639  3.292616       3.178505  1.927270e+06
# Townhouse             4.298759  3.165789       3.175454  2.056125e+06

# %%
def mode(series):
    return series.mode()
grouped_data = raw_data.groupby('title')
mode_data = grouped_data[['bedroom', 'bathroom', 'parking_space']].apply(mode)
print(mode_data)
# Out:
#                         bedroom  bathroom  parking_space
# title
# Apartment            0      1.0       1.0            4.0
# Bungalow             0      2.0       1.0            2.0
# Cottage              0      1.0       2.0            4.0
# Detached duplex      0      5.0       2.0            2.0
# Flat                 0      1.0       2.0            3.0
# Mansion              0      3.0       1.0            2.0
#                      1      NaN       NaN            3.0
# Penthouse            0      2.0       2.0            4.0
# Semi-detached duplex 0      5.0       2.0            3.0
# Terrace duplex       0      1.0       1.0            2.0
#                      1      2.0       NaN            4.0
# Townhouse            0      1.0       1.0            3.0

# %%
for house in house_types:
    sns.histplot(data=raw_data[raw_data['title'] == house], x='bedroom')
    plt.plot

# %%
for col in columns[3:]:
    sns.boxplot(data=raw_data, x=col, y='title')
    plt.title('Boxplot of {} by House type'.format(col))
    plt.xlabel('{}'.format(col))
    plt.ylabel('Type of house')
    plt.show()

# %%
columns
# Out:
# Index(['ID', 'loc', 'title', 'bedroom', 'bathroom', 'parking_space', 'price'], dtype='object')

# %%
sns.countplot(data=raw_data, y='loc')
plt.title("Frequency plot of locations")
plt.ylabel("Location")
plt.plot()
# Out:
# []

# %%
sns.countplot(data=raw_data, y='title')
plt.title("Frequency plot of house type")
plt.ylabel("Type of house")
plt.plot()
# Out:
# []

# %%
sns.barplot(data=raw_data, y='title', x='price')
plt.title("Price of houses by type")
plt.ylabel("Type of house")
plt.xlabel("Price")
plt.plot()
# Out:
# []

# %%
sns.barplot(data=raw_data, y='loc', x='price')
plt.title("Price of houses by location")
plt.ylabel("Location")
plt.xlabel("Price")
plt.plot()
# Out:
# []

# %%
sns.scatterplot(data=raw_data, y='bedroom', hue='bathroom', x='price')
plt.title("Scatterplot relating No of bedroom, No of bathroom and prices")
plt.xlabel('No of Bedroom(s)')
plt.ylabel('No of Bathroom(s)')
plt.plot()
# Out:
# []
